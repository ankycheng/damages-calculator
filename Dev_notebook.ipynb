# %%
import pandas as pd
from sqlalchemy import create_engine
import json
from pymongo import MongoClient

# %%
df = pd.read_pickle('statics/datas/result.pickle')

# %%
def dataframe_to_mongo(select_df):

    client = MongoClient('mongodb://hackmmurabi:ksfadacai@18.139.157.63:27017/')
    database = client["hackmmurabi"]  # SQL: Database Name
    collection = database["results"]   # SQL: Table Name


    records = select_df.to_dict('records') # 參數 record 代表把列轉成個別物件
    collection.insert_many(records)

# %%
client = MongoClient('mongodb://hackmmurabi:ksfadacai@18.139.157.63:27017/')
database = client["hackmmurabi"]  # SQL: Database Name
collection = database["results"]   # SQL: Table Name

# %%
datas = df.to_dict('records')

# %%
collection.insert_many(datas)

# %%
res = collection.find({}, {'judgement':1})

# %%
r_list = list(res)

# %%
# Out:
# 17940

# %%
df
# Out:
#            court                       date                       historyHash  \
# 1970    福建連江地方法院  2016-08-17T00:00:00+08:00  c74d75deba75b2c8cb3207d1910235d1
# 2012    福建金門地方法院  2012-02-15T00:00:00+08:00  2cb882cc11e9df8dc6d38f452f5924a3
# 2040    福建金門地方法院  2008-12-22T00:00:00+08:00
# 2041    福建金門地方法院  2009-05-21T00:00:00+08:00
# 2049    福建金門地方法院  2010-02-04T00:00:00+08:00  09f5f13c3a5b4352bfe848bc6cf41c39
# ...          ...                        ...                               ...
# 336303  臺灣臺北地方法院  2016-11-30T00:00:00+08:00
# 336394  臺灣臺北地方法院  2010-11-30T00:00:00+08:00  6f9df829438089157abefe922d2c2065
# 336425  臺灣臺北地方法院  2008-01-08T00:00:00+08:00  7617377c4b14c41fafb044ac1452ecdb
# 336438  臺灣臺北地方法院  2018-10-23T00:00:00+08:00
# 336475  臺灣臺北地方法院  2015-07-07T00:00:00+08:00
#
#                                                 judgement  \
# 1970    福建連江地方法院民事判決103年度訴字第9號原告盧冠華法定代理人林寶玉訴訟代理人黃正琪律師被...
# 2012    福建金門地方法院刑事附帶民事訴訟判決100年度交附民字第5號原告蔡啟政被告李錦珠上列當事人間...
# ...

# %%
a = df.iloc[0].keyword

# %%
a
# Out:
# [('油罐', 0.589751436422404),
#  ('822', 0.4991216061816835),
#  ('號機車', 0.26566150006444444),
#  ('莊秉諺', 0.23346010611723905),
#  ('盧冠良', 0.13685592427562288),
#  ('警大', 0.08050348486801347),
#  ('速率', 0.07895834746111785),
#  ('營區', 0.07245313638121212),
#  ('882', 0.07245313638121212),
#  ('超越', 0.06696183255622895),
#  ('鑑會', 0.06440278789441077),
#  ('大門', 0.06440278789441077),
#  ('灣電力', 0.05635243940760942),
#  ('祖營業', 0.05635243940760942),
#  ('連江車', 0.05635243940760942),
#  ('時速', 0.05635243940760942),
#  ('澳港區', 0.05635243940760942),
#  ('港區', 0.05635243940760942),
#  ('監視錄', 0.05635243940760942),
#  ('車右側', 0.05635243940760942),
#  ('車右', 0.048302090920808075),
#  ('閃爍', 0.048302090920808075),
#  ('相符', 0.04570816026812121),
#  ('安全措施', 0.0431587952610101),
#  ('道路交通', 0.04226493335484848),
#  ('連江', 0.04025174243400673),
#  ('076', 0.04025174243400673),
#  ('543', 0.04025174243400673),
#  ('碼頭', 0.04025174243400673),
#  ('澳港港', 0.04025174243400673)]

# %%
b = str(a)

# %%
c = b.split("),(")

# %%
c
# Out:
# ["[('油罐', 0.589751436422404), ('822', 0.4991216061816835), ('號機車', 0.26566150006444444), ('莊秉諺', 0.23346010611723905), ('盧冠良', 0.13685592427562288), ('警大', 0.08050348486801347), ('速率', 0.07895834746111785), ('營區', 0.07245313638121212), ('882', 0.07245313638121212), ('超越', 0.06696183255622895), ('鑑會', 0.06440278789441077), ('大門', 0.06440278789441077), ('灣電力', 0.05635243940760942), ('祖營業', 0.05635243940760942), ('連江車', 0.05635243940760942), ('時速', 0.05635243940760942), ('澳港區', 0.05635243940760942), ('港區', 0.05635243940760942), ('監視錄', 0.05635243940760942), ('車右側', 0.05635243940760942), ('車右', 0.048302090920808075), ('閃爍', 0.048302090920808075), ('相符', 0.04570816026812121), ('安全措施', 0.0431587952610101), ('道路交通', 0.04226493335484848), ('連江', 0.04025174243400673), ('076', 0.04025174243400673), ('543', 0.04025174243400673), ('碼頭', 0.04025174243400673), ('澳港港', 0.04025174243400673)]"]

# %%
host = 'aws-mysql.ctugs84fp5hq.ap-southeast-1.rds.amazonaws.com'
port = 3306
db = 'hackmmurabi'
user = 'admin'
password = 'password'

engine = create_engine(str(r"mysql+pymysql://%s:" + '%s' + "@%s/%s") % (user, password, host, db), 
                       pool_size=100, max_overflow=100, echo=False)

# %%
df.to_sql(name = 'results',con = engine,if_exists = 'append',index = False,index_label = False)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# ...

# %%
# 查詢語句，選出employee表中的所有資料
sql = '''
select * from employee;
'''
# read_sql_query的兩個引數: sql語句， 資料庫連線
df = pd.read_sql_query(sql, engine)
# 輸出employee表的查詢結果
print(df)
# 新建pandas中的DataFrame, 只有id,num兩列
df = pd.DataFrame({'id':[1,2,3,4],'num':[12,34,56,89]})
# 將新建的DataFrame儲存為MySQL中的資料表，不儲存index列
df.to_sql('mydf', engine, index= False)
print('Read from and write to Mysql table successfully!')
